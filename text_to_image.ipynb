# %% [markdown]
# <a href="https://colab.research.google.com/github/carlislejenkins/ChatBot/blob/master/text_to_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text-to-Image Search via CLIP
#
# <a href="https://colab.research.google.com/drive/1yKnmy2Qotrh3OhgwWRsMWPFwOSAecBxg?usp=sharing"><img alt="Open In Colab" src="https://colab.research.google.com/assets/colab-badge.svg"></a>
#
# Traditionally, searching images from text (text-image-retrieval) relies heavily on human annotations, this is commonly referred to as *Text/Tag-based Image Retrieval (TBIR)*.
#
# The [OpenAI CLIP](https://github.com/openai/CLIP) model maps the dense vectors extracted from text and image into the same semantic space and produces a strong zero-shot model to measure the similarity between text and images.
#
# This guide will showcase fine-tuning a `CLIP` model for text-to-image retrieval.
#
# *Note, please consider switching to GPU/TPU Runtime for faster inference.*
#
# ## Install

# %%
# !pip install 'finetuner[full]'
# Out:
# Collecting finetuner[full]
#   Downloading finetuner-0.8.1.tar.gz (39 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting docarray[common]<0.30.0 (from finetuner[full])
#   Downloading docarray-0.21.1.tar.gz (658 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 17.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting finetuner-stubs==0.13.10 (from finetuner[full])
#   Downloading finetuner_stubs-0.13.10-py3-none-any.whl (16 kB)
# Collecting finetuner-commons==0.13.10 (from finetuner[full])
#   Downloading finetuner_commons-0.13.10-py3-none-any.whl (39 kB)
# Collecting jina-hubble-sdk==0.33.1 (from finetuner[full])
#   Downloading jina_hubble_sdk-0.33.1-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 8.7 MB/s eta 0:00:00
# Collecting trimesh==3.16.4 (from finetuner[full])
#   Downloading trimesh-3.16.4-py3-none-any.whl (663 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 kB 53.5 MB/s eta 0:00:00
# Collecting onnx>1.11.0 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading onnx-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 97.8 MB/s eta 0:00:00
# Collecting onnxruntime>1.11.1 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 100.5 MB/s eta 0:00:00
# Collecting open-clip-torch==2.20.0 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading open_clip_torch-2.20.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.8 MB/s eta 0:00:00
# Requirement already satisfied: rich>=12.4.4 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (13.5.2)
# Requirement already satisfied: torchvision~=0.15.2 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (0.15.2+cu118)
# Requirement already satisfied: torch~=2.0.1 in /usr/local/lib/python3.10/dist-packages (from finetuner-commons==0.13.10->finetuner[full]) (2.0.1+cu118)
# Collecting transformers==4.20.1 (from finetuner-commons==0.13.10->finetuner[full])
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 106.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic~=1.10.11 in /usr/local/lib/python3.10/dist-packages (from finetuner-stubs==0.13.10->finetuner[full]) (1.10.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (2.31.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.8.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (3.12.2)
# Collecting pathspec (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading pathspec-0.11.2-py3-none-any.whl (29 kB)
# Collecting docker (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from jina-hubble-sdk==0.33.1->finetuner[full]) (6.0.1)
# Collecting python-jose (from jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading python_jose-3.3.0-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from trimesh==3.16.4->finetuner[full]) (1.23.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (2023.6.3)
# Collecting ftfy (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (4.66.1)
# Collecting huggingface-hub (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 32.4 MB/s eta 0:00:00
# Collecting sentencepiece (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<4 in /usr/local/lib/python3.10/dist-packages (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (3.20.3)
# Collecting timm (from open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading timm-0.9.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 101.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.20.1->finetuner-commons==0.13.10->finetuner[full]) (23.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers==4.20.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading tokenizers-0.12.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 94.2 MB/s eta 0:00:00
# Collecting lz4 (from docarray[common]<0.30.0->finetuner[full])
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (3.7.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from docarray[common]<0.30.0->finetuner[full]) (9.4.0)
# Collecting fastapi (from docarray[common]<0.30.0->finetuner[full])
#   Downloading fastapi-0.103.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.3 MB/s eta 0:00:00
# Collecting uvicorn (from docarray[common]<0.30.0->finetuner[full])
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.10/dist-packages (from onnx>1.11.0->finetuner-commons==0.13.10->finetuner[full]) (4.5.0)
# Collecting coloredlogs (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (23.5.26)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (1.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (2.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (16.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->jina-hubble-sdk==0.33.1->finetuner[full]) (1.3.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (2.0.4)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker->jina-hubble-sdk==0.33.1->finetuner[full]) (1.6.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->jina-hubble-sdk==0.33.1->finetuner[full]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->jina-hubble-sdk==0.33.1->finetuner[full]) (2023.7.22)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi->docarray[common]<0.30.0->finetuner[full]) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->docarray[common]<0.30.0->finetuner[full])
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->jina-hubble-sdk==0.33.1->finetuner[full]) (3.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->docarray[common]<0.30.0->finetuner[full]) (2.8.2)
# Collecting ecdsa!=0.15 (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full])
#   Downloading ecdsa-0.18.0-py2.py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (4.9)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (0.5.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->docarray[common]<0.30.0->finetuner[full]) (8.1.7)
# Collecting h11>=0.8 (from uvicorn->docarray[common]<0.30.0->finetuner[full])
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->docarray[common]<0.30.0->finetuner[full]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi->docarray[common]<0.30.0->finetuner[full]) (1.1.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from ecdsa!=0.15->python-jose->jina-hubble-sdk==0.33.1->finetuner[full]) (1.16.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (2023.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.4.4->finetuner-commons==0.13.10->finetuner[full]) (0.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full]) (0.2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch~=2.0.1->finetuner-commons==0.13.10->finetuner[full]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>1.11.1->finetuner-commons==0.13.10->finetuner[full]) (1.3.0)
# Collecting safetensors (from timm->open-clip-torch==2.20.0->finetuner-commons==0.13.10->finetuner[full])
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 87.4 MB/s eta 0:00:00
# Building wheels for collected packages: finetuner, docarray
#   Building wheel for finetuner (pyproject.toml) ... done
#   Created wheel for finetuner: filename=finetuner-0.8.1-py3-none-any.whl size=39368 sha256=4673579b3a6d166216085b57a30053df835972ef5680758f332adb40a729c36a
#   Stored in directory: /root/.cache/pip/wheels/f7/bb/41/863d09fad887b582f402ae8f1ac7c2e1add5d43c8f2c721bbd
#   Building wheel for docarray (pyproject.toml) ... done
#   Created wheel for docarray: filename=docarray-0.21.1-py3-none-any.whl size=721979 sha256=6fbb2f016d486505026f433029acbe506d421624eb99d8fa224ca527b8376cd2
#   Stored in directory: /root/.cache/pip/wheels/06/f4/c7/9a43755a64ffaa3d7e0998f3848dfdd46edaf0d76da5db4dee
# Successfully built finetuner docarray
# Installing collected packages: tokenizers, sentencepiece, safetensors, trimesh, pathspec, onnx, lz4, humanfriendly, h11, ftfy, ecdsa, uvicorn, starlette, python-jose, huggingface-hub, finetuner-stubs, docker, coloredlogs, transformers, onnxruntime, jina-hubble-sdk, fastapi, docarray, timm, open-clip-torch, finetuner-commons, finetuner
# Successfully installed coloredlogs-15.0.1 docarray-0.21.1 docker-6.1.3 ecdsa-0.18.0 fastapi-0.103.1 finetuner-0.8.1 finetuner-commons-0.13.10 finetuner-stubs-0.13.10 ftfy-6.1.1 h11-0.14.0 huggingface-hub-0.16.4 humanfriendly-10.0 jina-hubble-sdk-0.33.1 lz4-4.3.2 onnx-1.14.1 onnxruntime-1.15.1 open-clip-torch-2.20.0 pathspec-0.11.2 python-jose-3.3.0 safetensors-0.3.3 sentencepiece-0.1.99 starlette-0.27.0 timm-0.9.7 tokenizers-0.12.1 transformers-4.20.1 trimesh-3.16.4 uvicorn-0.23.2

# %% [markdown]
# ## Task
# We'll be fine-tuning CLIP on the [fashion captioning dataset](https://github.com/xuewyang/Fashion_Captioning) which contains information about fashion products.
#
# For each product, the dataset contains a title and images of multiple variants of the product. We constructed a parent [`Document`](https://docarray.jina.ai/fundamentals/document/#document) for each picture, which contains two [chunks](https://docarray.jina.ai/fundamentals/document/nested/#nested-structure): an image document and a text document holding the description of the product.

# %% [markdown]
# ## Data
# Our journey starts locally. We have to [prepare the data and push it to the Jina AI Cloud](https://finetuner.jina.ai/walkthrough/create-training-data/) and Finetuner will be able to get the dataset by its name. For this example,
# we already prepared the data, and we'll provide the names of training and evaluation data (`fashion-train-data-clip` and `fashion-eval-data-clip`) directly to Finetuner.
# In addition, we also provide labeled queries and an index of labeled documents for evaluating the retrieval capabilities of the resulting fine-tuned model stored in the datasets `fashion-eval-data-queries` and `fashion-eval-data-index`.
#
#
# ```{admonition} Push data to the cloud
# We don't require you to push data to the Jina AI Cloud by yourself. Instead of a name, you can provide a `DocumentArray` and Finetuner will do the job for you.
# When working with documents where images are stored locally, please call `doc.load_uri_to_blob()` to reduce network transmission and speed up training.
# ```

# %%
import finetuner
from docarray import DocumentArray, Document

finetuner.login(force=True)
# Out:
# VBox(children=(VBox(children=(HTML(value="\n<div class='custom-container'>\n    <style>\n        .button1 {\n …

# %%
train_data = DocumentArray.pull('finetuner/fashion-train-data-clip', show_progress=True)
eval_data = DocumentArray.pull('finetuner/fashion-eval-data-clip', show_progress=True)
query_data = DocumentArray.pull('finetuner/fashion-eval-data-queries', show_progress=True)
index_data = DocumentArray.pull('finetuner/fashion-eval-data-index', show_progress=True)

train_data.summary()
print(train_data)
# Out:
# 🔐 You are logged in to Jina AI as carlisle.jenkins (username: miilionaire-inc). To log out, use jina auth logout.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────── Documents Summary ─────────────────╮
# │                                                     │
# │   Type                      DocumentArrayInMemory   │
# │   Length                    12514                   │
# │   Homogenous Documents      True                    │
# │   Has nested Documents in   ('chunks',)             │
# │   Common Attributes         ('id', 'chunks')        │
# │   Multimodal dataclass      False                   │
# │                                                     │
# ╰─────────────────────────────────────────────────────╯
# ╭──────────────────────── Attributes Summary ────────────────────────╮
# │                                                                    │
# │   Attribute   Data type         #Unique values   Has empty value   │
# │  ────────────────────────────────────────────────────────────────  │
# │   chunks      ('ChunkArray',)   12514            False             │
# │   id          ('str',)          12514            False             │
# │                                                                    │
# ╰────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Backbone model
# Currently, we support several CLIP variations from [open-clip](https://github.com/mlfoundations/open_clip) for text to image retrieval tasks.
#
# However, you can see all available models either in [choose backbone](https://finetuner.jina.ai/walkthrough/choose-backbone/) section or by calling `finetuner.describe_models()`.

# %% [markdown]
# ## Fine-tuning
#
# Now that we have the training and evaluation datasets loaded as `DocumentArray`s and selected our model, we can start our fine-tuning run.

# %%
from finetuner.callback import EvaluationCallback

run = finetuner.fit(
    model='openai/clip-vit-base-patch32',
    train_data='finetuner/fashion-train-data-clip',
    eval_data='finetuner/fashion-eval-data-clip',
    epochs=5,
    learning_rate= 1e-7,
    loss='CLIPLoss',
    device='cuda',
    callbacks=[
        EvaluationCallback(
            model='clip-text',
            index_model='clip-vision',
            query_data='finetuner/fashion-eval-data-queries',
            index_data='finetuner/fashion-eval-data-index',
            gather_examples=True,
        )
    ],
)

# %% [markdown]
# Let's understand what this piece of code does:
#
# * We start with providing `model`, names of training and evaluation data.
# * We also provide some hyperparameters such as number of `epochs` and a `learning_rate`.
# * We use `CLIPLoss` to optimize the CLIP model.
# * We use an evaluation callback, which uses the `'clip-text'` model for encoding the text queries and the `'clip-vision'` model for encoding the images in `'fashion-eval-data-index'`.

# %% [markdown]
# ## Monitoring
#
# Now that we've created a run, let's see its status. You can monitor the run by checking the status - `run.status()` and - the logs - `run.logs()` or - `run.stream_logs()`.

# %%
# note, the fine-tuning might takes 20~ minutes
for entry in run.stream_logs():
    print(entry)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [00:20:14] INFO     Starting finetuner training run ...                                                  __main__.py:350
# DEBUG    Found Jina AI Cloud authentication token                                             __main__.py:362
# DEBUG    Running in online mode                                                               __main__.py:363
# INFO     Reading config ...                                                                   __main__.py:370
# DEBUG    Reading config from stream                                                           __main__.py:382
# INFO     Parsing config ...                                                                   __main__.py:385
# INFO     Config loaded 📜                                                                     __main__.py:389
# INFO     Run name: strange-wilbur                                                             __main__.py:391
# INFO     Experiment name: default                                                             __main__.py:392
# DEBUG    Device set to [cuda]                                                                 __main__.py:395
# DEBUG    Artifact ID set to 64fe5bd61d26925a60ca7416                                          __main__.py:141
# DEBUG    Artifact ID for metrics set to 64fe5bd61d26925a60ca7417                              __main__.py:144
# DEBUG    Artifact ID for example results set to 64fe5bd71d26925a60ca7418                      __main__.py:147
# INFO     Building the tuner components ...                                                    __main__.py:161
# INFO     Building models ...                                                                    tuning.py:326
# DEBUG    Model name: openai/clip-vit-base-patch32                                               tuning.py:328
# DEBUG    Model options: {}                                                                      tuning.py:329
# Downloading:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 4.09k/4.09k [00:00<00:00, 21.1MB/s]
# Downloading:   0%|          | 0.00/577M [00:00<?, ?B/s]
# Downloading:   1%|          | 5.40M/577M [00:00<00:10, 56.6MB/s]
# Downloading:   2%|▏         | 10.8M/577M [00:00<00:10, 56.8MB/s]
# Downloading:   3%|▎         | 16.3M/577M [00:00<00:10, 57.1MB/s]
# Downloading:   4%|▍         | 22.0M/577M [00:00<00:10, 58.1MB/s]
# Downloading:   5%|▍         | 27.7M/577M [00:00<00:09, 58.7MB/s]
# Downloading:   6%|▌         | 33.4M/577M [00:00<00:09, 59.1MB/s]
# Downloading:   7%|▋         | 39.1M/577M [00:00<00:09, 59.3MB/s]
# Downloading:   8%|▊         | 44.9M/577M [00:00<00:09, 59.6MB/s]
# Downloading:   9%|▉         | 50.6M/577M [00:00<00:09, 60.0MB/s]
# Downloading:  10%|▉         | 56.4M/577M [00:01<00:09, 60.1MB/s]
# Downloading:  11%|█         | 62.1M/577M [00:01<00:08, 60.1MB/s]
# Downloading:  12%|█▏        | 67.9M/577M [00:01<00:08, 60.1MB/s]
# Downloading:  13%|█▎        | 73.6M/577M [00:01<00:08, 60.0MB/s]
# Downloading:  14%|█▎        | 79.3M/577M [00:01<00:08, 60.0MB/s]
# Downloading:  15%|█▍        | 85.1M/577M [00:01<00:08, 60.0MB/s]
# Downloading:  16%|█▌        | 90.8M/577M [00:01<00:08, 60.2MB/s]
# Downloading:  17%|█▋        | 96.6M/577M [00:01<00:08, 60.1MB/s]
# Downloading:  18%|█▊        | 102M/577M [00:01<00:08, 60.1MB/s]
# Downloading:  19%|█▊        | 108M/577M [00:01<00:08, 60.0MB/s]
# Downloading:  20%|█▉        | 114M/577M [00:02<00:08, 60.0MB/s]
# Downloading:  21%|██        | 119M/577M [00:02<00:08, 60.0MB/s]
# Downloading:  22%|██▏       | 125M/577M [00:02<00:07, 59.8MB/s]
# Downloading:  23%|██▎       | 131M/577M [00:02<00:07, 59.7MB/s]
# Downloading:  24%|██▎       | 137M/577M [00:02<00:07, 59.7MB/s]
# Downloading:  25%|██▍       | 142M/577M [00:02<00:07, 59.7MB/s]
# Downloading:  26%|██▌       | 148M/577M [00:02<00:07, 59.6MB/s]
# Downloading:  27%|██▋       | 154M/577M [00:02<00:07, 59.5MB/s]
# Downloading:  28%|██▊       | 159M/577M [00:02<00:07, 59.6MB/s]
# Downloading:  29%|██▊       | 165M/577M [00:02<00:07, 59.8MB/s]
# Downloading:  30%|██▉       | 171M/577M [00:03<00:07, 59.9MB/s]
# Downloading:  31%|███       | 177M/577M [00:03<00:06, 60.1MB/s]
# Downloading:  32%|███▏      | 182M/577M [00:03<00:06, 59.5MB/s]
# Downloading:  33%|███▎      | 188M/577M [00:03<00:06, 59.0MB/s]
# Downloading:  34%|███▎      | 194M/577M [00:03<00:06, 59.3MB/s]
# Downloading:  35%|███▍      | 199M/577M [00:03<00:06, 59.5MB/s]
# Downloading:  36%|███▌      | 205M/577M [00:03<00:06, 59.7MB/s]
# Downloading:  37%|███▋      | 211M/577M [00:03<00:06, 59.9MB/s]
# Downloading:  38%|███▊      | 217M/577M [00:03<00:06, 59.9MB/s]
# Downloading:  39%|███▊      | 222M/577M [00:03<00:06, 59.9MB/s]
# Downloading:  40%|███▉      | 228M/577M [00:04<00:06, 60.0MB/s]
# Downloading:  41%|████      | 234M/577M [00:04<00:06, 59.3MB/s]
# Downloading:  42%|████▏     | 240M/577M [00:04<00:05, 59.3MB/s]
# Downloading:  42%|████▏     | 245M/577M [00:04<00:05, 59.3MB/s]
# Downloading:  43%|████▎     | 251M/577M [00:04<00:05, 59.5MB/s]
# Downloading:  44%|████▍     | 257M/577M [00:04<00:05, 59.0MB/s]
# Downloading:  45%|████▌     | 262M/577M [00:04<00:05, 59.1MB/s]
# Downloading:  46%|████▋     | 268M/577M [00:04<00:05, 59.1MB/s]
# Downloading:  47%|████▋     | 274M/577M [00:04<00:05, 59.4MB/s]
# Downloading:  48%|████▊     | 279M/577M [00:04<00:05, 59.6MB/s]
# Downloading:  49%|████▉     | 285M/577M [00:05<00:05, 59.7MB/s]
# Downloading:  50%|█████     | 291M/577M [00:05<00:05, 59.8MB/s]
# Downloading:  51%|█████▏    | 296M/577M [00:05<00:04, 59.6MB/s]
# Downloading:  52%|█████▏    | 302M/577M [00:05<00:04, 59.5MB/s]
# Downloading:  53%|█████▎    | 308M/577M [00:05<00:04, 59.5MB/s]
# Downloading:  54%|█████▍    | 314M/577M [00:05<00:04, 59.8MB/s]
# Downloading:  55%|█████▌    | 319M/577M [00:05<00:04, 59.8MB/s]
# Downloading:  56%|█████▋    | 325M/577M [00:05<00:04, 59.8MB/s]
# Downloading:  57%|█████▋    | 331M/577M [00:05<00:04, 59.8MB/s]
# Downloading:  58%|█████▊    | 336M/577M [00:05<00:04, 59.8MB/s]
# Downloading:  59%|█████▉    | 342M/577M [00:06<00:04, 59.7MB/s]
# Downloading:  60%|██████    | 348M/577M [00:06<00:04, 59.7MB/s]
# Downloading:  61%|██████▏   | 354M/577M [00:06<00:03, 59.7MB/s]
# Downloading:  62%|██████▏   | 359M/577M [00:06<00:03, 59.5MB/s]
# Downloading:  63%|██████▎   | 365M/577M [00:06<00:03, 59.6MB/s]
# Downloading:  64%|██████▍   | 371M/577M [00:06<00:03, 59.6MB/s]
# Downloading:  65%|██████▌   | 376M/577M [00:06<00:03, 59.8MB/s]
# Downloading:  66%|██████▌   | 382M/577M [00:06<00:03, 59.9MB/s]
# Downloading:  67%|██████▋   | 388M/577M [00:06<00:03, 59.6MB/s]
# Downloading:  68%|██████▊   | 394M/577M [00:06<00:03, 59.7MB/s]
# Downloading:  69%|██████▉   | 399M/577M [00:07<00:03, 59.7MB/s]
# Downloading:  70%|███████   | 405M/577M [00:07<00:03, 59.9MB/s]
# Downloading:  71%|███████   | 411M/577M [00:07<00:02, 60.1MB/s]
# Downloading:  72%|███████▏  | 417M/577M [00:07<00:02, 60.7MB/s]
# Downloading:  73%|███████▎  | 422M/577M [00:07<00:02, 60.6MB/s]
# Downloading:  74%|███████▍  | 428M/577M [00:07<00:02, 60.9MB/s]
# Downloading:  75%|███████▌  | 434M/577M [00:07<00:02, 61.1MB/s]
# Downloading:  76%|███████▌  | 440M/577M [00:07<00:02, 61.1MB/s]
# Downloading:  77%|███████▋  | 446M/577M [00:07<00:02, 61.1MB/s]
# Downloading:  78%|███████▊  | 452M/577M [00:07<00:02, 61.2MB/s]
# Downloading:  79%|███████▉  | 458M/577M [00:08<00:02, 61.2MB/s]
# Downloading:  80%|████████  | 463M/577M [00:08<00:01, 61.1MB/s]
# Downloading:  81%|████████▏ | 469M/577M [00:08<00:01, 60.9MB/s]
# Downloading:  82%|████████▏ | 475M/577M [00:08<00:01, 60.9MB/s]
# Downloading:  83%|████████▎ | 481M/577M [00:08<00:01, 60.6MB/s]
# Downloading:  84%|████████▍ | 487M/577M [00:08<00:01, 60.7MB/s]
# Downloading:  85%|████████▌ | 493M/577M [00:08<00:01, 60.8MB/s]
# Downloading:  86%|████████▋ | 498M/577M [00:08<00:01, 61.0MB/s]
# Downloading:  87%|████████▋ | 504M/577M [00:08<00:01, 61.0MB/s]
# Downloading:  88%|████████▊ | 510M/577M [00:08<00:01, 61.1MB/s]
# Downloading:  89%|████████▉ | 516M/577M [00:09<00:01, 61.2MB/s]
# Downloading:  90%|█████████ | 522M/577M [00:09<00:00, 61.0MB/s]
# Downloading:  91%|█████████▏| 528M/577M [00:09<00:00, 60.9MB/s]
# Downloading:  92%|█████████▏| 533M/577M [00:09<00:00, 61.1MB/s]
# Downloading:  93%|█████████▎| 539M/577M [00:09<00:00, 61.1MB/s]
# Downloading:  94%|█████████▍| 545M/577M [00:09<00:00, 61.4MB/s]
# Downloading:  95%|█████████▌| 551M/577M [00:09<00:00, 61.4MB/s]
# Downloading:  96%|█████████▋| 557M/577M [00:09<00:00, 61.3MB/s]
# Downloading:  97%|█████████▋| 563M/577M [00:09<00:00, 61.4MB/s]
# Downloading:  99%|█████████▊| 569M/577M [00:09<00:00, 61.4MB/s]
# Downloading: 100%|█████████▉| 574M/577M [00:10<00:00, 61.4MB/s]
# Downloading: 100%|██████████| 577M/577M [00:10<00:00, 60.1MB/s]
# Downloading:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 568/568 [00:00<00:00, 5.25MB/s]
# Downloading:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 842k/842k [00:00<00:00, 40.8MB/s]
# Downloading:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading:  19%|█▉        | 97.0k/512k [00:00<00:00, 555kB/s]
# Downloading: 100%|██████████| 512k/512k [00:00<00:00, 1.91MB/s]
# Downloading:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Downloading: 100%|██████████| 2.12M/2.12M [00:00<00:00, 23.7MB/s]
# Downloading:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 389/389 [00:00<00:00, 2.46MB/s]
# Downloading:   0%|          | 0.00/316 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 316/316 [00:00<00:00, 2.54MB/s]
# [00:20:30] INFO     Loading the training data ...                                                          tuning.py:158
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# 🔐 You are logged in to Jina AI as carlisle.jenkins (username: miilionaire-inc). To log out, use jina auth logout.
# ping
# 2023-09-11 00:20:42.274690
# ping
# 2023-09-11 00:20:57.274244
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12514/12514 • 348 QPS • 0:00:00 • 318.5 MB
# [00:20:58] DEBUG    # training samples: 12514                                                              tuning.py:171
# INFO     Building loss ...                                                                      tuning.py:431
# DEBUG    Loss name: CLIPLoss                                                                    tuning.py:432
# DEBUG    Loss options: {}                                                                       tuning.py:433
# [00:21:00] DEBUG    Saving initial state of the model                                                    batchsize.py:86
# ping
# 2023-09-11 00:21:12.274589
# ping
# 2023-09-11 00:21:27.274709
# [00:21:18] DEBUG    Testing batch size of 8                                                             batchsize.py:122
# [00:21:19] DEBUG    Testing batch size of 16                                                            batchsize.py:122
# DEBUG    Testing batch size of 32                                                            batchsize.py:122
# [00:21:20] DEBUG    Testing batch size of 64                                                            batchsize.py:122
# [00:21:21] DEBUG    Testing batch size of 128                                                           batchsize.py:122
# [00:21:22] DEBUG    Testing batch size of 256                                                           batchsize.py:122
# [00:21:25] DEBUG    Testing batch size of 512                                                           batchsize.py:122
# [00:21:28] DEBUG    Batch_size adjusted from 4 to 256                                                    batchsize.py:91
# DEBUG    Restoring initial state of the model                                                 batchsize.py:93
# [00:21:29] INFO     Loading the evaluation data ...                                                        tuning.py:255
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# ping
# 2023-09-11 00:21:42.274597
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 613 QPS • 0:00:00 • 20.3 MB
# [00:21:33] DEBUG    # eval samples: 787                                                                    tuning.py:262
# INFO     Building loss ...                                                                      tuning.py:431
# DEBUG    Loss name: CLIPLoss                                                                    tuning.py:432
# DEBUG    Loss options: {}                                                                       tuning.py:433
# INFO     Building optimizer ...                                                                 tuning.py:538
# DEBUG    Optimizer name: Adam                                                                   tuning.py:539
# DEBUG    Optimizer options: {'lr': 1e-07}                                                       tuning.py:540
# INFO     Building callback 'EvaluationCallback' ...                                             tuning.py:815
# DEBUG    Callback options: {'query_data': 'finetuner/fashion-eval-data-queries', 'index_data':  tuning.py:816
# 'finetuner/fashion-eval-data-index', 'model': 'clip-text', 'index_model':
# 'clip-vision', 'multi_modal': False, 'batch_size': 32, 'exclude_self': True, 'limit':
# 20, 'distance': 'cosine', 'steps_per_interval': None, 'gather_examples': True,
# 'num_example_queries': 5, 'num_workers': 8, 'caption': None, 'output_model_names':
# False, 'query_sample_size': None}
# INFO     Loading the query data ...                                                             tuning.py:646
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 9951 QPS • 0:00:00 • 119.1 kB
# [00:21:36] INFO     Loading the index data ...                                                             tuning.py:654
# INFO     Pulling data from cloud storage ...                                                      utils.py:80
# Deserializing ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 787/787 • 668 QPS • 0:00:00 • 20.2 MB
# [00:21:41] DEBUG    # index samples: 787                                                                   tuning.py:659
# INFO     Model, data, callbacks, loss, miner and optimizer built successfully 🔥              __main__.py:165
# INFO     Finetuning ...                                                                       __main__.py:170
# [00:21:45] DEBUG    Evaluation result at epoch: 0/5 is:                                                evaluation.py:387
# DEBUG    Metric: 'precision_at_k' Value: 0.02992                                            evaluation.py:389
# DEBUG    Metric: 'recall_at_k' Value: 0.03177                                               evaluation.py:389
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02887                                             evaluation.py:389
# DEBUG    Metric: 'hit_at_k' Value: 0.23380                                                  evaluation.py:389
# DEBUG    Metric: 'average_precision' Value: 0.05229                                         evaluation.py:389
# DEBUG    Metric: 'reciprocal_rank' Value: 0.06668                                           evaluation.py:389
# DEBUG    Metric: 'dcg_at_k' Value: 0.21027                                                  evaluation.py:389
# DEBUG    Example results at epoch: 0/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dad00868-9f4e-4139-ab3f-60ebd6513ec5.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/3610d9f7-9b0d-4ba2-8921-a56902c3a876.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/3610d9f7-9b0d-4ba2-8921-a56902c3a876.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dad00868-9f4e-4139-ab3f-60ebd6513ec5.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-09-11 00:21:57.274702
# ping
# 2023-09-11 00:22:12.274997
# ping
# 2023-09-11 00:22:27.275461
# [00:22:30] DEBUG    Evaluation result at epoch: 1/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02433                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.04193                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02808                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.34689                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.07183                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.08621                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.19508                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 1/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ec2e277-9297-4172-884a-8c5ad7ce8a9e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1e83e948-e82a-41ff-bb3f-24350f1958b6.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ec2e277-9297-4172-884a-8c5ad7ce8a9e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/e21d0e75-f0e5-41b1-895d-154e7851526b.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-09-11 00:22:42.275480
# ping
# 2023-09-11 00:22:57.275461
# ping
# 2023-09-11 00:23:12.275442
# [00:23:15] DEBUG    Evaluation result at epoch: 2/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02592                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.04193                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02925                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.29987                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.07309                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.09122                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.21317                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 2/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ec2e277-9297-4172-884a-8c5ad7ce8a9e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/0dfcd20f-f9b3-4915-99fb-a81fb9a1b43d.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1e83e948-e82a-41ff-bb3f-24350f1958b6.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b53eae6e-9ae2-4c41-9f29-abd0d33ae5c4.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-09-11 00:23:27.275753
# ping
# 2023-09-11 00:23:42.275170
# ping
# 2023-09-11 00:23:57.275491
# [00:24:01] DEBUG    Evaluation result at epoch: 3/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02668                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.04320                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.03031                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.28971                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.06780                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.08653                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.21006                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 3/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/5936bc00-8283-4bb1-af8a-49db3362704c.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b75d4faf-dea3-40af-9995-c47847f87286.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/f2d41cb3-d61a-44b1-8fef-7ad998a5619e.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/0aa1a1d0-5228-475c-87af-00db38e62fbb.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/e326440b-e4f3-4b60-84a0-2a6c60eef3db.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-09-11 00:24:12.275532
# ping
# 2023-09-11 00:24:27.275990
# ping
# 2023-09-11 00:24:42.276736
# [00:24:47] DEBUG    Evaluation result at epoch: 4/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.02427                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.04320                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.02900                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.30877                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.06970                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.07785                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.21911                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 4/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ebd3b90-ee33-4074-a508-0539207c2e33.jpeg
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/bacf4db4-cfbd-4e1c-b452-5cba91c1de83.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b75d4faf-dea3-40af-9995-c47847f87286.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/a9164903-c308-4f6b-8935-8ec38c8dddd6.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/8dec219a-b1fb-4d96-88c3-dafe4dc6f956.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b4db7b42-6dd9-44d3-9cd5-880b3a6ab1f8.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/dc4007f9-558f-4e21-9791-3ec2ccf5cd99.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# ping
# 2023-09-11 00:24:57.276205
# ping
# 2023-09-11 00:25:12.276183
# ping
# 2023-09-11 00:25:27.276557
# [00:25:32] DEBUG    Evaluation result at epoch: 5/5 is:                                                evaluation.py:404
# DEBUG    Metric: 'precision_at_k' Value: 0.03355                                            evaluation.py:406
# DEBUG    Metric: 'recall_at_k' Value: 0.05718                                               evaluation.py:406
# DEBUG    Metric: 'f1_score_at_k' Value: 0.03979                                             evaluation.py:406
# DEBUG    Metric: 'hit_at_k' Value: 0.43964                                                  evaluation.py:406
# DEBUG    Metric: 'average_precision' Value: 0.07933                                         evaluation.py:406
# DEBUG    Metric: 'reciprocal_rank' Value: 0.08123                                           evaluation.py:406
# DEBUG    Metric: 'dcg_at_k' Value: 0.25137                                                  evaluation.py:406
# DEBUG                                                                                       evaluation.py:407
# DEBUG    Example results at epoch: 5/5:                                                     evaluation.py:255
# DEBUG    Query: original play speckled platform waterproof rain boot                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/23eb3d9a-99d9-434a-8f18-e760aa02eba1.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ebd3b90-ee33-4074-a508-0539207c2e33.jpeg
# DEBUG    Query: marietten slingback sandal                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/eda375f8-4b53-4fe2-aeca-73570cb588c9.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/2cbc9b4c-1d70-4611-ac66-2e941bced262.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/c86b0201-a705-4713-839e-9ccde97c20de.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: v neck long cardigan                                                        evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b4db7b42-6dd9-44d3-9cd5-880b3a6ab1f8.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/51a5ef1c-fda7-497d-953b-2ecc18d28322.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: animal print mock neck top                                                  evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/b4db7b42-6dd9-44d3-9cd5-880b3a6ab1f8.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG    Query: west village tunic cover up                                                 evaluation.py:268
# DEBUG            1:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            2:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop
# =pad&pad_color=FFF...
# DEBUG            3:                                                                         evaluation.py:273
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop
# =pad&pad_color=FFF...
# Training [5/5] ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97/97 0:00:00 0:00:39 • loss: 5.459 • val_loss: 5.494
# [00:25:33] INFO     Done ✨                                                                              __main__.py:192
# DEBUG    Finetuning took 0 days, 0 hours 3 minutes and 51 seconds                             __main__.py:194
# INFO     Metric: 'precision_at_k' before fine-tuning:  0.02992 after fine-tuning: 0.03355     __main__.py:207
# INFO     Metric: 'recall_at_k' before fine-tuning:  0.03177 after fine-tuning: 0.05718        __main__.py:207
# INFO     Metric: 'f1_score_at_k' before fine-tuning:  0.02887 after fine-tuning: 0.03979      __main__.py:207
# INFO     Metric: 'hit_at_k' before fine-tuning:  0.23380 after fine-tuning: 0.43964           __main__.py:207
# INFO     Metric: 'average_precision' before fine-tuning:  0.05229 after fine-tuning: 0.07933  __main__.py:207
# INFO     Metric: 'reciprocal_rank' before fine-tuning:  0.06668 after fine-tuning: 0.08123    __main__.py:207
# INFO     Metric: 'dcg_at_k' before fine-tuning:  0.21027 after fine-tuning: 0.25137           __main__.py:207
# INFO     Example results for query: 'original play speckled platform waterproof rain boot':   __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/dad00868-9f4e-4139-ab3f-60ebd6513ec5.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/23eb3d9a-99d9-434a-8f18-e760aa02eba1.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/ca51586d-d1df-4f8b-9c56-69eb0739a696.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3: https://n.nordstrommedia.com/id/sr3/1ebd3b90-ee33-4074-a508-0539207c2e33.jpeg     __main__.py:229
# INFO     Example results for query: 'marietten slingback sandal':                             __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/3610d9f7-9b0d-4ba2-8921-a56902c3a876.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/eda375f8-4b53-4fe2-aeca-73570cb588c9.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/2cbc9b4c-1d70-4611-ac66-2e941bced262.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/c86b0201-a705-4713-839e-9ccde97c20de.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'v neck long cardigan':                                   __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/3610d9f7-9b0d-4ba2-8921-a56902c3a876.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/b4db7b42-6dd9-44d3-9cd5-880b3a6ab1f8.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/51a5ef1c-fda7-497d-953b-2ecc18d28322.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'animal print mock neck top':                             __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/dad00868-9f4e-4139-ab3f-60ebd6513ec5.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/b4db7b42-6dd9-44d3-9cd5-880b3a6ab1f8.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Example results for query: 'west village tunic cover up':                            __main__.py:224
# INFO     Before fine-tuning:                                                                  __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/085f05b5-bd82-400e-b0f0-5715eb155b1e.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/f55727b1-616c-4234-b46d-f1ba1623d61c.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/3a8f9cdb-78c9-4bfe-953b-d3817f52b12b.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     After fine-tuning:                                                                   __main__.py:227
# INFO     1:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/1ae0a7d7-427a-4187-a241-2ebf88ccd57a.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     2:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/64a6fe88-f526-4a00-893c-14601e5afe09.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     3:                                                                                   __main__.py:229
# https://n.nordstrommedia.com/id/sr3/47ad79b9-cc6c-40f5-93ac-ce40f2fa5fe7.jpeg?crop=p
# ad&pad_color=FFF&format=jpeg&w=60&h=90
# INFO     Building the artifact ...                                                            __main__.py:231
# INFO     Pushing artifact to Jina AI Cloud ...                                                __main__.py:260
# ping
# 2023-09-11 00:25:42.276805
# ping
# 2023-09-11 00:25:57.276253
# ping
# 2023-09-11 00:26:12.276529
# ping
# 2023-09-11 00:26:27.276189
# ping
# 2023-09-11 00:26:42.276740
# ping
# 2023-09-11 00:26:57.276809
# ping
# 2023-09-11 00:27:12.277031
# [00:27:09] INFO     Artifact pushed under ID '64fe5bd61d26925a60ca7416'                                  __main__.py:266
# DEBUG    Artifact size is 535.393 MB                                                          __main__.py:268
# INFO     Finished 🚀                                                                          __main__.py:415
# time="2023-09-11T00:27:11.568Z" level=info msg="sub-process exited" argo=true error="<nil>"

# %% [markdown]
# Since some runs might take up to several hours/days, it's important to know how to reconnect to Finetuner and retrieve your run.
#
# ```python
# import finetuner
#
# finetuner.login()
# run = finetuner.get_run(run.name)
# ```
#
# You can continue monitoring the run by checking the status - `finetuner.run.Run.status()` or the logs - `finetuner.run.Run.logs()`.

# %% [markdown]
# ## Evaluating
#
# Our `EvaluationCallback` during fine-tuning ensures that after each epoch, an evaluation of our model is run. We can access the results of the last evaluation in the logs as follows `print(run.logs())`:
#
# ```bash
#   Training [5/5] ━━━━ 195/195 0:00… 0:0… • loss: 2.419 • val_loss: 2.803
# [13:32:41] INFO     Done ✨                              __main__.py:195
#            DEBUG    Finetuning took 0 days, 0 hours 5 minutes and 30 seconds
#            DEBUG    Metric: 'clip-text-to-clip-vision_precision_at_k' Value: 0.28532
#            DEBUG    Metric: 'clip-text-to-clip-vision_hit_at_k' Value: 0.94282
#            DEBUG    Metric: 'clip-text-to-clip-vision_average_precision' Value: 0.53372
#            DEBUG    Metric: 'clip-text-to-clip-vision_reciprocal_rank' Value: 0.67706
#            DEBUG    Metric: 'clip-text-to-clip-vision_dcg_at_k' Value: 2.71247
# ...
# ```

# %% [markdown]
# ## Saving
#
# After the run has finished successfully, you can download the tuned model on your local machine:

# %%
artifact = run.save_artifact('clip-model')
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Inference
#
# Now you saved the `artifact` into your host machine,
# let's use the fine-tuned model to encode a new `Document`:

# %%
text_da = DocumentArray([Document(text='some text to encode')])
image_da = DocumentArray([Document(uri='https://upload.wikimedia.org/wikipedia/commons/4/4e/Single_apple.png')])

clip_text_encoder = finetuner.get_model(artifact=artifact, select_model='clip-text')
clip_image_encoder = finetuner.get_model(artifact=artifact, select_model='clip-vision')

finetuner.encode(model=clip_text_encoder, data=text_da)
finetuner.encode(model=clip_image_encoder, data=image_da)

print(text_da.embeddings.shape)
print(image_da.embeddings.shape)
# Out:
# Downloading:   0%|          | 0.00/568 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.09k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/842k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/512k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/389 [00:00<?, ?B/s]

# %% [markdown]
# ```bash
# (1, 512)
# (1, 512)
# ```
#
# ```{admonition} what is select_model?
# When fine-tuning CLIP, we are fine-tuning the CLIPVisionEncoder and CLIPTextEncoder in parallel.
# The artifact contains two models: `clip-vision` and `clip-text`.
# The parameter `select_model` tells finetuner which model to use for inference, in the above example,
# we use `clip-text` to encode a Document with text content.
# ```
#
# ```{admonition} Inference with ONNX
# In case you set `to_onnx=True` when calling `finetuner.fit` function,
# please use `model = finetuner.get_model(artifact, is_onnx=True)`
# ```

# %% [markdown]
# ## Advanced: WiSE-FT
#
# WiSE-FT, proposed by Mitchell et al. in [Robust fine-tuning of zero-shot models](https://arxiv.org/abs/2109.01903),
# has been proven to be an effective way for fine-tuning models with a strong zero-shot capability,
# such as CLIP.
# As was introduced in the paper:
#
# > Large pre-trained models such as CLIP or ALIGN offer consistent accuracy across a range of data distributions when performing zero-shot inference (i.e., without fine-tuning on a specific dataset). Although existing fine-tuning methods substantially improve accuracy on a given target distribution, they often reduce robustness to distribution shifts. We address this tension by introducing a simple and effective method for improving robustness while fine-tuning: ensembling the weights of the zero-shot and fine-tuned models (WiSE-FT).
#
# Finetuner allows you to apply WiSE-FT easily,
# all you need to do is use the `WiSEFTCallback`.
# Finetuner will trigger the callback when the fine-tuning job is finished and merge the weights between the pre-trained model and the fine-tuned model:
#
# ```diff
# from finetuner.callback import WiSEFTCallback
#
# run = finetuner.fit(
#     model='ViT-B-32#openai',
#     ...,
#     loss='CLIPLoss',
# -   callbacks=[],
# +   callbacks=[WiSEFTCallback(alpha=0.5)],
# )
# ```
#
# The value you set for `alpha` should be greater than or equal to 0 and less than or equal to 1:
#
# + if `alpha` is a float between 0 and 1, we merge the weights between the pre-trained model and the fine-tuned model.
# + if `alpha` is 0, the fine-tuned model is identical to the pre-trained model.
# + if `alpha` is 1, the pre-trained weights will not be utilized.
#
#
# That's it! Check out [clip-as-service](https://clip-as-service.jina.ai/user-guides/finetuner/?highlight=finetuner#fine-tune-models) to learn how to plug in a fine-tuned CLIP model to our CLIP-specific service.

# %% [markdown]
# ## Before and after
# We can directly compare the results of our fine-tuned model with a pre-trained clip model by displaying the matches each model has for the same query. While the differences between the results of the two models are quite subtle for some queries, the examples below clearly show that finetuning increases the quality of the search results:

# %% [markdown]
# ```plaintext
# Results for query: "nightingale tee jacket" using a zero-shot model (top) and the fine-tuned model (bottom)
# ```
# ![clip-example-pt](https://user-images.githubusercontent.com/6599259/212634395-6f336d39-cda7-425d-80a2-10facae3b824.png)
#
# ![clip-example-ft](https://user-images.githubusercontent.com/6599259/212634112-a44c6c4c-2cc1-4dfb-8e29-0d02b2d6b95c.png)
